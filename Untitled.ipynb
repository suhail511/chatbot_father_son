# %%
import pandas as pd
import numpy as np
import os
import re
from datetime import datetime
import glob
import codecs
from nltk.tokenize import sent_tokenize,word_tokenize
import sys
import math
import pickle

def cleanMessage(message):
    # Remove new lines within message
    cleanedMessage = message.replace('\n','')
#     cleanedMessage = message.replace('\?','').lower()
    # Remove punctuation
    # 	cleanedMessage = re.sub('\(\[\]\)','', cleanedMessage)
    # Remove multiple spaces in message
    cleanedMessage = re.sub(' +',' ', cleanedMessage)
    cleanedMessage = re.sub('-+','-', cleanedMessage)
    cleanedMessage = re.sub('…',' ', cleanedMessage)
    cleanedMessage = re.sub('\.+','.', cleanedMessage)
    return cleanedMessage

def takeCareOfLongMessages(theDict):

    newresponseDictionary = theDict
    keys = []
    values = []
    for k,v in responseDictionary.items():
        keys.append(k)
        values.append(v)

    for index,key in enumerate(keys):
        if len(word_tokenize(key)) >= 50 or len(word_tokenize(values[index])) >= 50 :
            key_sentences = sent_tokenize(key)
            value_sentences = sent_tokenize(values[index])

            for number, value_sentence in enumerate(value_sentences):
                for key_sentence in key_sentences:
                    for i in range(number):
                        key_sentence += ' <pad> '
                    newresponseDictionary[key_sentence] = value_sentence

    return newresponseDictionary

#Read files and Remove empty lines
filenames = sorted(glob.glob('files/002.txt'))
print("Files found: ", filenames)

allLines = []
for filename in filenames:
	with codecs.open(filename, "r", "utf-8") as file:
		allLines.append(file.readlines())
allLines = [item for sublist in allLines for item in sublist]
while '\n' in allLines: allLines.remove('\n')

#This is for the son
personName = 'son'

responseDictionary = dict()
myMessage, otherPersonsMessage, currentSpeaker = "","",""
for index,lines in enumerate(allLines):
    justMessage = lines
    colon = justMessage.find(':')
    # Find messages of the current person
    if (justMessage[:colon] == personName):
        if not myMessage:
            # Want to find the first message that person send (if sent multiple in a row)
            startMessageIndex = index - 1
        myMessage += justMessage[colon+1:]

    elif myMessage:
        # Now go and see what message the other person sent by looking at previous messages
        for counter in range(startMessageIndex, 0, -1):
            currentLine = allLines[counter]
            justMessage = currentLine
            colon = justMessage.find(':')
            if not currentSpeaker:
                # Other speaker
                currentSpeaker = justMessage[:colon]
            elif (currentSpeaker != justMessage[:colon] and otherPersonsMessage):
                # A different person started speaking, so now I know that the first person's message is done
                otherPersonsMessage = cleanMessage(otherPersonsMessage)
                myMessage = cleanMessage(myMessage)
#                 otherPersonsMessage += ' endofmessage '
#                 myMessage += ' endofmessage '
                responseDictionary[otherPersonsMessage] = myMessage
                break
            otherPersonsMessage = justMessage[colon+1:] + otherPersonsMessage
        if startMessageIndex < 1:
            justMessage = lines
            colon = justMessage.find(':')
            otherPersonsMessage = justMessage[colon+1:]
            otherPersonsMessage = cleanMessage(otherPersonsMessage)
            currentLine = allLines[2]
            colon = currentLine.find(':')
            myMessage = cleanMessage(currentLine[colon+1:])
#             otherPersonsMessage += ' endofmessage '
#             myMessage += ' endofmessage '
            responseDictionary[otherPersonsMessage] = myMessage
        myMessage, otherPersonsMessage, currentSpeaker = "","",""

responseDictionary = takeCareOfLongMessages(responseDictionary)
        
np.save('data/sonConversationDictionary.npy', responseDictionary)

conversationFile = open('data/sonConversationData.txt', 'w')
for key,value in responseDictionary.items():
    if (not key.strip() or not value.strip()):
        # If there are empty strings
        continue
    conversationFile.write(key.strip() + ' ' + value.strip() + ' ')

conversationFile.close()
# Out:
# Files found:  ['files/002.txt']

# %%
len(responseDictionary)
# Out:
# 94

# %%
{k: responseDictionary[k] for k in list(responseDictionary)[:5]}
responseDictionary
# Out:
# {" Well when you first came here I mean through the door on the very first day, firstly, what it was is that we wasn't actually warned that you was coming. What it was that we was told that the social worker was coming round just to discuss with us about you coming and when I seen you come through the door I looked and I thought Well social workers are getting younger and younger. And you came up the stairs and it was obviously you and your sister here together and the very first impressions that I got was that your sister was out of her depth and and quite a bit frightened and that you'd sort of step forward as as the as the as the the big brother. And you was going to take on this responsibility of coming here and making sure that everything was okay for you and your sister. So I'm a bit protective towards your sister. I think after a while because it was obviously news to us as well and we were sort of you know trying to feel our way with it and it was just an hour or so after the first meeting. And I think after a while you did sort of relax when you maybe I don't know what you thought maybe that that's that was gonna be some sort of prison but obviously it's just a family. Normal family and I felt that you sort of relaxed then you felt well maybe you know it's not going to be too bad for us after all.": ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever. It\'s like I know if I need anything I can come to you two and I know that you\'ll do anything you can to help me because it is like family.',
#  " Well after the first interview that you. Well interview is not really the right word to use but the first meeting that we had. And you went back and obviously spoke to the social worker because you'd still got a choice about it then and obviously you chose to come here and give it a go. I mean what I mean Angela was acutely aware of that it must be extremely difficult you know to move away from everything that you knew up to that date in your life really. Your family and it was your mother And to move away and coming to a different environment, a different location and another family really. We sort of tried really to put you at ease to make you feel at home to the best of our ability you know, but that road had its ups and downs with it and you can't do that overnight because it is, well I felt it was sort of difficult to sort of adjust to a different family a different location. So really we sort of started to go down that road towards making you as you know as comfortable and as happy as possible. I mean it wasn't always easy because you know you were leaving your mom and you've got a strong relationship with your mom.": " Well, didn't.",
#  " Well you know your mom had got to a point that she couldn't cope anymore and what happened was, I mean because mom became part of the family as well didn't she.": ' Yeah.',
#  " You know I mean your mom used to come here and I think that that was everybody didn't look on it as you. your mom didn't look at it as though somebody else were taking over her children. She looked at that it in the way that she knew she couldn't cope. But she also would checked out where you were and was making sure that you were okay and because of the work together with your mom and with us and that that also made you feel comfortable because you didn't have to make any choices between your mum or us. It was more than enhancing what you've already got and what's the state now is that you're close to your mum, to us and nobody feels threatened in any way as to who you know well sometimes when kids come into care they have to make a choice and it's very difficult for them because they are born with parents but the parents don't like that that bonding. So they'll try and disrupt it, but Mark's mum didn't do that. And I think that helped an awful lot. At what stage were you at when you arrived here?": " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum. But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons. I mean my anger was tied to my mom but really I directed it everywhere. I wasn't channeling it because there was just too much channel. And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed. I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.",
#  " Mm hmm. Well that's what that's what we realised when you came here I mean that your mom had cared for you up to this stage, however there were some issues there back in the past which is the reason that you came into care but in a sense your mom was a sort of victim for many reasons and that we really felt that we needed to bring your mother in to keep her into the relationship that you got with me and Angela and keep your family together.": ' And she she came in and she got on really well with Angela. I mean she got on with you as well I mean when we went for contact it wasn\'t just like "there you go the kids" or "there\'s the budget" or whatever it was like "how is everything going" "how are things with you?" - it was a conversation it wasn\'t just like two people just given the kids over giving whatever over, it was like a little conversation and it was just like dropping us off to see a family member it was like dropping us off to go see a nan or something. Well really it was my mum, but other than that it was just so easy.',
#  " I mean I feel that she didn't desert you in any way shape or form. I mean I think that she did what she felt was best for you at that time which must have been very very difficult for her very difficult and she sort of worked with us as an extended family group and kept contact with you both, you and your sister and she sort of gave permission really for you to attach to us. She didn't make it difficult for us and that helped us to no end. And it's it's helped you as well I think.": ' It helped you helped me in a way because if she had been there, kind of saying conflicting things I would have been conflicted I would have been kind of confused but she was well every time we were talking about you and Angela too or when we went see her she was joining the conversation. She was actually saying to us "I\'m so glad I made that decision because you got things now and you\'re doing things now that I could never have given you you\'ve, got the chance to do things that you really wanted to do, things that you dreamed about doing and staying with me you would have never been able to do" so with that she was the one saying to us "it\'s the best decision that we could have made for you".',
#  " Well when you first came here I mean through the door on the very first day, firstly, what it was is that we wasn't actually warned that you was coming.": ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  'What it was that we was told that the social worker was coming round just to discuss with us about you coming and when I seen you come through the door I looked and I thought Well social workers are getting younger and younger.': ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  "And you came up the stairs and it was obviously you and your sister here together and the very first impressions that I got was that your sister was out of her depth and and quite a bit frightened and that you'd sort of step forward as as the as the as the the big brother.": ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  'And you was going to take on this responsibility of coming here and making sure that everything was okay for you and your sister.': ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  "So I'm a bit protective towards your sister.": ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  'I think after a while because it was obviously news to us as well and we were sort of you know trying to feel our way with it and it was just an hour or so after the first meeting.': ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  "And I think after a while you did sort of relax when you maybe I don't know what you thought maybe that that's that was gonna be some sort of prison but obviously it's just a family.": ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  "Normal family and I felt that you sort of relaxed then you felt well maybe you know it's not going to be too bad for us after all.": ' Well I did feel that I mean after the first few first few weeks and first few months obviously we settled and we met the wider family members of yours and Angela\'s family and within a year or so we were like family - I mean I still talk to Brendan Now he\'s like a cousin to me I mean we\'re really close and God with all your daughters I mean God we\'re both for you too I mean you\'re like the dad I never had and Angela is like a second mom to me so it\'s like is really the family thing it\'s not like other people see it like "oh they\'re outsiders\', stick them in a different room or we\'re not going to talk to them or whatever.',
#  " Well when you first came here I mean through the door on the very first day, firstly, what it was is that we wasn't actually warned that you was coming. <pad> ": "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  'What it was that we was told that the social worker was coming round just to discuss with us about you coming and when I seen you come through the door I looked and I thought Well social workers are getting younger and younger. <pad> ': "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  "And you came up the stairs and it was obviously you and your sister here together and the very first impressions that I got was that your sister was out of her depth and and quite a bit frightened and that you'd sort of step forward as as the as the as the the big brother. <pad> ": "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  'And you was going to take on this responsibility of coming here and making sure that everything was okay for you and your sister. <pad> ': "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  "So I'm a bit protective towards your sister. <pad> ": "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  'I think after a while because it was obviously news to us as well and we were sort of you know trying to feel our way with it and it was just an hour or so after the first meeting. <pad> ': "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  "And I think after a while you did sort of relax when you maybe I don't know what you thought maybe that that's that was gonna be some sort of prison but obviously it's just a family. <pad> ": "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  "Normal family and I felt that you sort of relaxed then you felt well maybe you know it's not going to be too bad for us after all. <pad> ": "It's like I know if I need anything I can come to you two and I know that you'll do anything you can to help me because it is like family.",
#  ' Well after the first interview that you.': " Well, didn't.",
#  'Well interview is not really the right word to use but the first meeting that we had.': " Well, didn't.",
#  "And you went back and obviously spoke to the social worker because you'd still got a choice about it then and obviously you chose to come here and give it a go.": " Well, didn't.",
#  'I mean what I mean Angela was acutely aware of that it must be extremely difficult you know to move away from everything that you knew up to that date in your life really.': " Well, didn't.",
#  'Your family and it was your mother And to move away and coming to a different environment, a different location and another family really.': " Well, didn't.",
#  "We sort of tried really to put you at ease to make you feel at home to the best of our ability you know, but that road had its ups and downs with it and you can't do that overnight because it is, well I felt it was sort of difficult to sort of adjust to a different family a different location.": " Well, didn't.",
#  'So really we sort of started to go down that road towards making you as you know as comfortable and as happy as possible.': " Well, didn't.",
#  "I mean it wasn't always easy because you know you were leaving your mom and you've got a strong relationship with your mom.": " Well, didn't.",
#  " You know I mean your mom used to come here and I think that that was everybody didn't look on it as you.": " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  "your mom didn't look at it as though somebody else were taking over her children.": " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  "She looked at that it in the way that she knew she couldn't cope.": " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  "But she also would checked out where you were and was making sure that you were okay and because of the work together with your mom and with us and that that also made you feel comfortable because you didn't have to make any choices between your mum or us.": " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  "It was more than enhancing what you've already got and what's the state now is that you're close to your mum, to us and nobody feels threatened in any way as to who you know well sometimes when kids come into care they have to make a choice and it's very difficult for them because they are born with parents but the parents don't like that that bonding.": " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  "So they'll try and disrupt it, but Mark's mum didn't do that.": " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  'And I think that helped an awful lot.': " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  'At what stage were you at when you arrived here?': " Well it was kind of like I didn't really have, well I kind of had a relationship with my mum.",
#  " You know I mean your mom used to come here and I think that that was everybody didn't look on it as you. <pad> ": "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  "your mom didn't look at it as though somebody else were taking over her children. <pad> ": "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  "She looked at that it in the way that she knew she couldn't cope. <pad> ": "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  "But she also would checked out where you were and was making sure that you were okay and because of the work together with your mom and with us and that that also made you feel comfortable because you didn't have to make any choices between your mum or us. <pad> ": "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  "It was more than enhancing what you've already got and what's the state now is that you're close to your mum, to us and nobody feels threatened in any way as to who you know well sometimes when kids come into care they have to make a choice and it's very difficult for them because they are born with parents but the parents don't like that that bonding. <pad> ": "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  "So they'll try and disrupt it, but Mark's mum didn't do that. <pad> ": "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  'And I think that helped an awful lot. <pad> ': "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  'At what stage were you at when you arrived here? <pad> ': "But, it wasn't that strong and I was kind of in a place where I resented my mum for all the moves and all the things that happened and I was angry at everyone for really my own reasons.",
#  " You know I mean your mom used to come here and I think that that was everybody didn't look on it as you. <pad>  <pad> ": 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  "your mom didn't look at it as though somebody else were taking over her children. <pad>  <pad> ": 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  "She looked at that it in the way that she knew she couldn't cope. <pad>  <pad> ": 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  "But she also would checked out where you were and was making sure that you were okay and because of the work together with your mom and with us and that that also made you feel comfortable because you didn't have to make any choices between your mum or us. <pad>  <pad> ": 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  "It was more than enhancing what you've already got and what's the state now is that you're close to your mum, to us and nobody feels threatened in any way as to who you know well sometimes when kids come into care they have to make a choice and it's very difficult for them because they are born with parents but the parents don't like that that bonding. <pad>  <pad> ": 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  "So they'll try and disrupt it, but Mark's mum didn't do that. <pad>  <pad> ": 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  'And I think that helped an awful lot. <pad>  <pad> ': 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  'At what stage were you at when you arrived here? <pad>  <pad> ': 'I mean my anger was tied to my mom but really I directed it everywhere.',
#  " You know I mean your mom used to come here and I think that that was everybody didn't look on it as you. <pad>  <pad>  <pad> ": "I wasn't channeling it because there was just too much channel.",
#  "your mom didn't look at it as though somebody else were taking over her children. <pad>  <pad>  <pad> ": "I wasn't channeling it because there was just too much channel.",
#  "She looked at that it in the way that she knew she couldn't cope. <pad>  <pad>  <pad> ": "I wasn't channeling it because there was just too much channel.",
#  "But she also would checked out where you were and was making sure that you were okay and because of the work together with your mom and with us and that that also made you feel comfortable because you didn't have to make any choices between your mum or us. <pad>  <pad>  <pad> ": "I wasn't channeling it because there was just too much channel.",
#  "It was more than enhancing what you've already got and what's the state now is that you're close to your mum, to us and nobody feels threatened in any way as to who you know well sometimes when kids come into care they have to make a choice and it's very difficult for them because they are born with parents but the parents don't like that that bonding. <pad>  <pad>  <pad> ": "I wasn't channeling it because there was just too much channel.",
#  "So they'll try and disrupt it, but Mark's mum didn't do that. <pad>  <pad>  <pad> ": "I wasn't channeling it because there was just too much channel.",
#  'And I think that helped an awful lot. <pad>  <pad>  <pad> ': "I wasn't channeling it because there was just too much channel.",
#  'At what stage were you at when you arrived here? <pad>  <pad>  <pad> ': "I wasn't channeling it because there was just too much channel.",
#  " You know I mean your mom used to come here and I think that that was everybody didn't look on it as you. <pad>  <pad>  <pad>  <pad> ": 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  "your mom didn't look at it as though somebody else were taking over her children. <pad>  <pad>  <pad>  <pad> ": 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  "She looked at that it in the way that she knew she couldn't cope. <pad>  <pad>  <pad>  <pad> ": 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  "But she also would checked out where you were and was making sure that you were okay and because of the work together with your mom and with us and that that also made you feel comfortable because you didn't have to make any choices between your mum or us. <pad>  <pad>  <pad>  <pad> ": 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  "It was more than enhancing what you've already got and what's the state now is that you're close to your mum, to us and nobody feels threatened in any way as to who you know well sometimes when kids come into care they have to make a choice and it's very difficult for them because they are born with parents but the parents don't like that that bonding. <pad>  <pad>  <pad>  <pad> ": 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  "So they'll try and disrupt it, but Mark's mum didn't do that. <pad>  <pad>  <pad>  <pad> ": 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  'And I think that helped an awful lot. <pad>  <pad>  <pad>  <pad> ': 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  'At what stage were you at when you arrived here? <pad>  <pad>  <pad>  <pad> ': 'And going back on that it was kind of like everything that was familiar to me was the anger, the pain and the stress and then coming here and the pain and the stress were gone really quickly I mean, the anger stayed.',
#  " You know I mean your mom used to come here and I think that that was everybody didn't look on it as you. <pad>  <pad>  <pad>  <pad>  <pad> ": 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  "your mom didn't look at it as though somebody else were taking over her children. <pad>  <pad>  <pad>  <pad>  <pad> ": 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  "She looked at that it in the way that she knew she couldn't cope. <pad>  <pad>  <pad>  <pad>  <pad> ": 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  "But she also would checked out where you were and was making sure that you were okay and because of the work together with your mom and with us and that that also made you feel comfortable because you didn't have to make any choices between your mum or us. <pad>  <pad>  <pad>  <pad>  <pad> ": 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  "It was more than enhancing what you've already got and what's the state now is that you're close to your mum, to us and nobody feels threatened in any way as to who you know well sometimes when kids come into care they have to make a choice and it's very difficult for them because they are born with parents but the parents don't like that that bonding. <pad>  <pad>  <pad>  <pad>  <pad> ": 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  "So they'll try and disrupt it, but Mark's mum didn't do that. <pad>  <pad>  <pad>  <pad>  <pad> ": 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  'And I think that helped an awful lot. <pad>  <pad>  <pad>  <pad>  <pad> ': 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  'At what stage were you at when you arrived here? <pad>  <pad>  <pad>  <pad>  <pad> ': 'I mean obviously we worked through that over the last couple years but other than that a lot of things calmed down and actually I did get a stronger relationship with my mom because of you and Angela and it was like having that stability there to help me to do that which you provided.',
#  ' Mm hmm.': ' And she she came in and she got on really well with Angela.',
#  "Well that's what that's what we realised when you came here I mean that your mom had cared for you up to this stage, however there were some issues there back in the past which is the reason that you came into care but in a sense your mom was a sort of victim for many reasons and that we really felt that we needed to bring your mother in to keep her into the relationship that you got with me and Angela and keep your family together.": ' And she she came in and she got on really well with Angela.',
#  ' Mm hmm. <pad> ': 'I mean she got on with you as well I mean when we went for contact it wasn\'t just like "there you go the kids" or "there\'s the budget" or whatever it was like "how is everything going" "how are things with you?"',
#  "Well that's what that's what we realised when you came here I mean that your mom had cared for you up to this stage, however there were some issues there back in the past which is the reason that you came into care but in a sense your mom was a sort of victim for many reasons and that we really felt that we needed to bring your mother in to keep her into the relationship that you got with me and Angela and keep your family together. <pad> ": 'I mean she got on with you as well I mean when we went for contact it wasn\'t just like "there you go the kids" or "there\'s the budget" or whatever it was like "how is everything going" "how are things with you?"',
#  ' Mm hmm. <pad>  <pad> ': "- it was a conversation it wasn't just like two people just given the kids over giving whatever over, it was like a little conversation and it was just like dropping us off to see a family member it was like dropping us off to go see a nan or something.",
#  "Well that's what that's what we realised when you came here I mean that your mom had cared for you up to this stage, however there were some issues there back in the past which is the reason that you came into care but in a sense your mom was a sort of victim for many reasons and that we really felt that we needed to bring your mother in to keep her into the relationship that you got with me and Angela and keep your family together. <pad>  <pad> ": "- it was a conversation it wasn't just like two people just given the kids over giving whatever over, it was like a little conversation and it was just like dropping us off to see a family member it was like dropping us off to go see a nan or something.",
#  ' Mm hmm. <pad>  <pad>  <pad> ': 'Well really it was my mum, but other than that it was just so easy.',
#  "Well that's what that's what we realised when you came here I mean that your mom had cared for you up to this stage, however there were some issues there back in the past which is the reason that you came into care but in a sense your mom was a sort of victim for many reasons and that we really felt that we needed to bring your mother in to keep her into the relationship that you got with me and Angela and keep your family together. <pad>  <pad>  <pad> ": 'Well really it was my mum, but other than that it was just so easy.',
#  " I mean I feel that she didn't desert you in any way shape or form.": ' It helped you helped me in a way because if she had been there, kind of saying conflicting things I would have been conflicted I would have been kind of confused but she was well every time we were talking about you and Angela too or when we went see her she was joining the conversation.',
#  'I mean I think that she did what she felt was best for you at that time which must have been very very difficult for her very difficult and she sort of worked with us as an extended family group and kept contact with you both, you and your sister and she sort of gave permission really for you to attach to us.': ' It helped you helped me in a way because if she had been there, kind of saying conflicting things I would have been conflicted I would have been kind of confused but she was well every time we were talking about you and Angela too or when we went see her she was joining the conversation.',
#  "She didn't make it difficult for us and that helped us to no end.": ' It helped you helped me in a way because if she had been there, kind of saying conflicting things I would have been conflicted I would have been kind of confused but she was well every time we were talking about you and Angela too or when we went see her she was joining the conversation.',
#  "And it's it's helped you as well I think.": ' It helped you helped me in a way because if she had been there, kind of saying conflicting things I would have been conflicted I would have been kind of confused but she was well every time we were talking about you and Angela too or when we went see her she was joining the conversation.',
#  " I mean I feel that she didn't desert you in any way shape or form. <pad> ": 'She was actually saying to us "I\'m so glad I made that decision because you got things now and you\'re doing things now that I could never have given you you\'ve, got the chance to do things that you really wanted to do, things that you dreamed about doing and staying with me you would have never been able to do" so with that she was the one saying to us "it\'s the best decision that we could have made for you".',
#  'I mean I think that she did what she felt was best for you at that time which must have been very very difficult for her very difficult and she sort of worked with us as an extended family group and kept contact with you both, you and your sister and she sort of gave permission really for you to attach to us. <pad> ': 'She was actually saying to us "I\'m so glad I made that decision because you got things now and you\'re doing things now that I could never have given you you\'ve, got the chance to do things that you really wanted to do, things that you dreamed about doing and staying with me you would have never been able to do" so with that she was the one saying to us "it\'s the best decision that we could have made for you".',
#  "She didn't make it difficult for us and that helped us to no end. <pad> ": 'She was actually saying to us "I\'m so glad I made that decision because you got things now and you\'re doing things now that I could never have given you you\'ve, got the chance to do things that you really wanted to do, things that you dreamed about doing and staying with me you would have never been able to do" so with that she was the one saying to us "it\'s the best decision that we could have made for you".',
#  "And it's it's helped you as well I think. <pad> ": 'She was actually saying to us "I\'m so glad I made that decision because you got things now and you\'re doing things now that I could never have given you you\'ve, got the chance to do things that you really wanted to do, things that you dreamed about doing and staying with me you would have never been able to do" so with that she was the one saying to us "it\'s the best decision that we could have made for you".'}

# %%
def cleanDict(datasetDictionary):
    if "I." in datasetDictionary: datasetDictionary.remove("I.")
    return datasetDictionary
    

def processDataset(filename):
    openedFile = open(filename, 'r')
    allLines = openedFile.readlines()
    myStr = ""
    for line in allLines:
        myStr += line
    finalDict = list(set(word_tokenize(myStr)))
#     print(myStr)
    return myStr, finalDict

fullCorpus, datasetDictionary = processDataset('data/sonConversationData.txt')
print('Finished parsing and cleaning dataset')

# Remove unwanted words/foul langua etc.
datasetDictionary = cleanDict(datasetDictionary)
wordList = list(datasetDictionary)

with open("data/SonWordList.txt", "wb") as fp:
	pickle.dump(wordList, fp)
print('Created file data/SonWordList.txt')
# Out:
# Finished parsing and cleaning dataset
# Created file data/SonWordList.txt

# %%
datasetDictionary
# Out:
# ['somebody',
#  'victim',
#  'it',
#  'ups',
#  'ability',
#  'wanted',
#  'know',
#  'use',
#  'best',
#  'work',
#  'that',
#  'forward',
#  'through',
#  'few',
#  'point',
#  "'re",
#  'became',
#  'any',
#  'can',
#  'social',
#  'settled',
#  'meeting',
#  'actually',
#  'after',
#  'protective',
#  'so',
#  'date',
#  'talking',
#  'right',
#  'went',
#  'mum',
#  'its',
#  'at',
#  'trying',
#  'used',
#  'shape',
#  'kind',
#  'okay',
#  'resented',
#  'or',
#  'Your',
#  'end',
#  'been',
#  'never',
#  'made',
#  'So',
#  'issues',
#  'different',
#  'directed',
#  'taking',
#  'had',
#  'ca',
#  'giving',
#  'things',
#  'prison',
#  'do',
#  'all',
#  'spoke',
#  'dreamed',
#  'Angela',
#  'last',
#  'attach',
#  'sort',
#  'sister',
#  "'ve",
#  'here',
#  'both',
#  'sense',
#  'discuss',
#  'go',
#  '``',
#  'interview',
#  'anymore',
#  'everywhere',
#  'felt',
#  'everyone',
#  'two',
#  'place',
#  'move',
#  'nobody',
#  'cope',
#  'yours',
#  'need',
#  'then',
#  'off',
#  'them',
#  'sure',
#  'She',
#  'anything',
#  'disrupt',
#  'younger',
#  'downs',
#  'an',
#  'about',
#  'staying',
#  'within',
#  'while',
#  'frightened',
#  'stress',
#  'conflicting',
#  'choices',
#  'gon',
#  'when',
#  'helped',
#  'than',
#  'making',
#  'overnight',
#  'me',
#  'What',
#  'came',
#  'Now',
#  'depth',
#  'permission',
#  'choice',
#  'Mark',
#  'anger',
#  'up',
#  'environment',
#  'what',
#  'think',
#  'bonding',
#  'thing',
#  'difficult',
#  'desert',
#  'every',
#  '-',
#  'leaving',
#  'your',
#  'feels',
#  'impressions',
#  'would',
#  'months',
#  'outsiders',
#  'kids',
#  'did',
#  'a',
#  'first',
#  'state',
#  'confused',
#  'weeks',
#  'stronger',
#  'way',
#  'this',
#  'familiar',
#  'sometimes',
#  'Mm',
#  'my',
#  'knew',
#  'going',
#  'one',
#  'past',
#  'on',
#  'year',
#  'nan',
#  'look',
#  'tried',
#  'try',
#  'seen',
#  'over',
#  'God',
#  'happy',
#  'Brendan',
#  'started',
#  'if',
#  'the',
#  'extended',
#  'though',
#  '?',
#  'pain',
#  'daughters',
#  'easy',
#  'possible',
#  'I',
#  'own',
#  'down',
#  'life',
#  'We',
#  'just',
#  'from',
#  'comfortable',
#  'stairs',
#  'acutely',
#  'else',
#  'other',
#  'able',
#  'happened',
#  'care',
#  'must',
#  'relax',
#  ',',
#  'help',
#  'oh',
#  'moves',
#  'get',
#  'But',
#  "'d",
#  'relaxed',
#  'keep',
#  'stick',
#  'chance',
#  'contact',
#  'strong',
#  'are',
#  'workers',
#  'ease',
#  'still',
#  'we',
#  'no',
#  'have',
#  'budget',
#  'step',
#  'adjust',
#  'as',
#  'already',
#  'everything',
#  'stability',
#  'looked',
#  'decision',
#  'member',
#  'because',
#  'form',
#  'reasons',
#  'feel',
#  'people',
#  'who',
#  'always',
#  'relationship',
#  'worker',
#  "n't",
#  'joining',
#  '.',
#  'It',
#  'told',
#  'not',
#  "'m",
#  'us',
#  'met',
#  'see',
#  'many',
#  'and',
#  "'s",
#  'between',
#  'provided',
#  'firstly',
#  'for',
#  'everybody',
#  'thought',
#  'second',
#  'children',
#  'needed',
#  'bring',
#  'cousin',
#  'with',
#  'family',
#  'her',
#  'also',
#  'gave',
#  'be',
#  'very',
#  'which',
#  'how',
#  'At',
#  'Well',
#  'angry',
#  'na',
#  'conflicted',
#  'worked',
#  'something',
#  'road',
#  'years',
#  'checked',
#  'stage',
#  'more',
#  'having',
#  'reason',
#  'lot',
#  'towards',
#  'threatened',
#  'but',
#  'were',
#  'channeling',
#  'mom',
#  'close',
#  'there',
#  'too',
#  'couple',
#  'little',
#  'well',
#  'saying',
#  'much',
#  'she',
#  'getting',
#  'make',
#  'is',
#  'room',
#  'conversation',
#  'hour',
#  'awful',
#  'Yeah',
#  'bad',
#  'realised',
#  'location',
#  'they',
#  'bit',
#  'part',
#  'you',
#  'maybe',
#  'could',
#  'talk',
#  'like',
#  'away',
#  'together',
#  'mother',
#  'to',
#  'where',
#  'channel',
#  'word',
#  'wider',
#  'was',
#  'You',
#  'extremely',
#  'day',
#  'take',
#  'doing',
#  'in',
#  'aware',
#  'And',
#  'news',
#  'Normal',
#  'time',
#  'responsibility',
#  'come',
#  'group',
#  'got',
#  'however',
#  'coming',
#  'tied',
#  'given',
#  'quite',
#  'parents',
#  'quickly',
#  'big',
#  'give',
#  'arrived',
#  'warned',
#  'out',
#  'calmed',
#  'he',
#  'into',
#  "''",
#  'obviously',
#  'gone',
#  'members',
#  'round',
#  'chose',
#  'now',
#  'our',
#  'kept',
#  'of',
#  'home',
#  'enhancing',
#  'stayed',
#  'really',
#  "'",
#  'born',
#  'whatever',
#  "'ll",
#  'cared',
#  'dropping',
#  'brother',
#  'another',
#  'back',
#  'put',
#  'mean',
#  'some',
#  'dad',
#  'door',
#  'hmm',
#  'glad']
