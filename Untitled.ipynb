# %%
import tensorflow as tf
import numpy as np
import re
from collections import Counter
import sys
import math
from random import randint
import pickle
import os

# This Word2Vec implementation is largely based on this paper
# https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf
# It's a bit old, but Word2Vec is still SOTA and relatively simple, so I'm going with it

# Check out Tensorflow's documentation which is pretty good for Word2Vec
# https://www.tensorflow.org/tutorials/word2vec

# wordVecDimensions = 100
# batchSize = 128
# numNegativeSample = 64
# windowSize = 5
# numIterations = 100000

# This function just takes in the conversation data and makes it
# into one huge string, and then uses a Counter to identify words
# and the number of occurences
def processDataset(filename):
	openedFile = open(filename, 'r')
	allLines = openedFile.readlines()
	myStr = ""
	for line in allLines:
	    myStr += line
	finalDict = Counter(myStr.split())
	return myStr, finalDict

# def createTrainingMatrices(dictionary, corpus):
# 	allUniqueWords = list(dictionary.keys())
# 	allWords = corpus.split()
# 	numTotalWords = len(allWords)
# 	xTrain=[]
# 	yTrain=[]
# 	for i in range(numTotalWords):
# 		if i % 100000 == 0:
# 			print('Finished %d/%d total words' % (i, numTotalWords))
# 		wordsAfter = allWords[i + 1:i + windowSize + 1]
# 		wordsBefore = allWords[max(0, i - windowSize):i]
# 		wordsAdded = wordsAfter + wordsBefore
# 		for word in wordsAdded:
# 			xTrain.append(allUniqueWords.index(allWords[i]))
# 			yTrain.append(allUniqueWords.index(word))
# 	return xTrain, yTrain
#
# def getTrainingBatch():
# 	num = randint(0,numTrainingExamples - batchSize - 1)
# 	arr = xTrain[num:num + batchSize]
# 	labels = yTrain[num:num + batchSize]
# 	return arr, np.array(labels)[:,np.newaxis]


# continueWord2Vec = True
# Loading the data structures if they are present in the directory
# if (os.path.isfile('data/FatherWord2VecXTrain.npy') and os.path.isfile('data/FatherWord2VecYTrain.npy') and os.path.isfile('data/FatherWordList.txt')):
# 	xTrain = np.load('data/FatherWord2VecXTrain.npy')
# 	yTrain = np.load('data/FatherWord2VecYTrain.npy')
# 	print('Finished loading training matrices')
# 	with open("data/FatherWordList.txt", "rb") as fp:
# 		wordList = pickle.load(fp)
# 	print('Finished loading word list')
#
# else:
fullCorpus, datasetDictionary = processDataset('data/FatherConversationData.txt')
print('Finished parsing and cleaning dataset')
wordList = list(datasetDictionary.keys())
# createOwnVectors = input('Do you want to create your own vectors through Word2Vec (y/n)?')
# if (createOwnVectors == 'y'):
# 	xTrain, yTrain  = createTrainingMatrices(datasetDictionary, fullCorpus)
# 	print('Finished creating training matrices')
# 	np.save('Word2VecXTrain.npy', xTrain)
# 	np.save('Word2VecYTrain.npy', yTrain)
# else:
# continueWord2Vec = False
with open("data/FatherWordList.txt", "wb") as fp:
	pickle.dump(wordList, fp)
print('Created file data/FatherWordList.txt')

print(wordList)

# If you do not want to create your own word vectors and you'd just like to
# have Tensorflow's seq2seq take care of that, then you don't need to run
# anything below this line.
# if (continueWord2Vec == False):
# 	sys.exit()
#
# numTrainingExamples = len(xTrain)
# vocabSize = len(wordList)
#
# sess = tf.Session()
# embeddingMatrix = tf.Variable(tf.random_uniform([vocabSize, wordVecDimensions], -1.0, 1.0))
# nceWeights = tf.Variable(tf.truncated_normal([vocabSize, wordVecDimensions], stddev=1.0 / math.sqrt(wordVecDimensions)))
# nceBiases = tf.Variable(tf.zeros([vocabSize]))
#
# inputs = tf.placeholder(tf.int32, shape=[batchSize])
# outputs = tf.placeholder(tf.int32, shape=[batchSize, 1])
#
# embed = tf.nn.embedding_lookup(embeddingMatrix, inputs)
#
# loss = tf.reduce_mean(
#   tf.nn.nce_loss(weights=nceWeights,
#                  biases=nceBiases,
#                  labels=outputs,
#                  inputs=embed,
#                  num_sampled=numNegativeSample,
#                  num_classes=vocabSize))
#
# optimizer = tf.train.GradientDescentOptimizer(learning_rate=1.0).minimize(loss)
#
# sess.run(tf.global_variables_initializer())
# for i in range(numIterations):
# 	trainInputs, trainLabels = getTrainingBatch()
# 	_, curLoss = sess.run([optimizer, loss], feed_dict={inputs: trainInputs, outputs: trainLabels})
# 	if (i % 10000 == 0):
# 		print ('Current loss is:', curLoss)
# print ('Saving the word embedding matrix')
# embedMatrix = embeddingMatrix.eval(session=sess)
# np.save('embeddingMatrix.npy', embedMatrix)
# Out:
# Finished parsing and cleaning dataset
# Created file data/FatherWordList.txt
# ['hey', 'dad', "let's", 'talk', 'about', 'your', 'childhood', 'i’ve', 'always', 'been', 'curious', 'you', 'know', 'i', 'was', 'never', 'as', 'good', 'of', 'a', 'kid', 'you’ve', 'mentioned', 'think', 'it', 'different', 'growing', 'up', 'in', 'smaller', 'city', 'probably', 'london', 'is', 'bit', 'weird', 'one', 'what', 'way', 'don’t', 'sort', 'get', 'used', 'to', 'having', 'so', 'many', 'things', 'and', 'people', 'around', 'that', 'makes', 'sense', 'honestly', 'just', 'looking', 'for', 'something', 'pass', 'the', 'time', 'like', 'well', 'there', 'bicycle', 'wanted', 'more', 'than', 'anything', 'when', 'remember', 'this', 'story', 'vaguely', 'happened', 'got', 'science', 'kit', 'my', 'birthday', 'crappy', 'ones', 'can', 'buy', 'toy', 'shop', 'yes', 'but', 'did', 'collected', 'same', 'chemical', 'over', 'again', 'from', 'pharmacies', 'enough', 'make', 'explosion', 'enormous', '…', 'blew', 'roof', 'off', 'house', 'hole', '-', 'parents', 'were', 'poor', 'we', 'lived', 'with', 'our', 'months', 'say', 'they', 'both', 'angry', 'had', 'lot', 'love', 'me', 'fine', 'end', 'winter', 'thankfully', 'not', 'quite', 'cold', 'though', 'at', 'times', 'do', 'back', 'those', 'very', 'fondly', 'however', 'life', 'simple', 'maybe', 'that’s', 'how', 'no', 'yep', 'everything', 'being', 'much', 'easier', 'wake', 'watch', 'cartoons', 'on', 'saturday', 'pancakes', 'smell', 'most', 'feeling', 'warm', 'sun', 'coming', 'through', 'windows', 'all', 'plants', 'have', 'course', 'important', 'grow', 'really', 'why', 'i’m', 'entirely', 'sure', 'because', 'younger', 'struggle', 'accept', 'big', 'disposal', 'including', 'middle', 'class', 'family', 'nothing', 'handed', 'feel', 'such', 'an', 'integral', 'part', 'education', 'fend', 'myself', 'assumed', 'learn', 'stuff', 'too', 'young', 'age', 'mean', 'it’s', 'force', 'go', 'out', 'shops', 'dark', 'or', 'getting', 'motorbike', 'scary', 'yeah', 'best', 'move', 'be', '‘streetwise’', 'ten', 'years', 'old', 'would', 'come', 'naturally', 'sorry…', 'these', 'didn’t', 'sometimes', 'ok', 'now', 'glad', 'father', 'loved', 'him', 'difficult', 'said', 'tried', 'better', 'holidays', 'food', 'etc…', 'doesn’t', 'less', 'surely', 'oh', 'completely', 'even', 'understand', 'effort', 'he', 'put', 'into', 'making', 'communist', 'wasn’t', 'party', 'while', 'grew', 'socialist', 'giving', 'if', 'needed', 'lacking', 'today', 'grandpa', 'bring', 'home', 'homeless', 'drive', 'grandma', 'insane', 'honest', 'caring', 'am', 'others', 'trustworthy', 'grandma’s', 'side', 'incident…', 'incident', 'basically', 'brought', 'guy', 'sleep', 'bare', 'mind', 'space', 'uncle', 'yeah…', 'anyways', 'gone', 'unusual', 'he’s', 'spent', 'night', 'right', 'bathroom', 'literally', 'smeared', 'shit', 'walls', 'clean', 'up…', 'man…', 'rough', 'courage', 'trust', 'wrath', 'sad', 'knew', 'yet', 'still', 'miss', 'god', 'sister', 'few', 'clear', 'memories', 'chateau', 'lignan', 'where', 'holiday', 'south', 'france', 'some', 'visit', 'us', 'lola', 'presents', 'snotty', 'stupid', 'appreciating', 'his', 'gifts', 'smile', 'thank', 'nice', 'inside', 'thinking', 'colouring', 'books', 'pencils', 'etc', 'touch', 'guys', 'money', 'spend', 'cried', 'see', 'beautiful', 'gesture', 'amazing', 'man', 'was…', 'wear', 'gold', 'chain', 'gifted', 'once', 'wait', 'actually', 'subject', 'enjoyed', 'then', 'length', 'other', "wouldn't", 'whereas', 'grandmother', "it's", 'she', 'likes', "don't", "she'd", 'idea', 'kind', 'wish', 'fault', 'thin', 'guitar', 'pendant', 'recently', 'found', 'year', 'ago', 'take', 'seeing', 'neck', 'taking', 'piss', 'look', 'gangster', 'grandpas', 'took', 'comes', 'sweet', 'bet', 'happy', 'hear', 'hope', 'regret', 'bought', 'new', 'dog', 'certainly', 'emotional', 'respected', 'older', 'respect', 'tap', 'their', 'emotions', 'we’re', 'talking—', 'minute', 'okay', 'son', 'please', 'does', 'moment', 'i…', 'nope', 'can’t', 'wait…what', 'like…ten', 'sat', 'down', 'seven', 'math', 'tutor', 'worth', '“ahem', 'uh…listen', 'want', 'differently…if', 'ever', 'begin', '‘bec ...

# %%
# Out:
# ['hey',
#  'dad',
#  "let's",
#  'talk',
#  'about',
#  'your',
#  'childhood',
#  'i’ve',
#  'always',
#  'been',
#  'curious',
#  'you',
#  'know',
#  'i',
#  'was',
#  'never',
#  'as',
#  'good',
#  'of',
#  'a',
#  'kid',
#  'you’ve',
#  'mentioned',
#  'think',
#  'it',
#  'different',
#  'growing',
#  'up',
#  'in',
#  'smaller',
#  'city',
#  'probably',
#  'london',
#  'is',
#  'bit',
#  'weird',
#  'one',
#  'what',
#  'way',
#  'don’t',
#  'sort',
#  'get',
#  'used',
#  'to',
#  'having',
#  'so',
#  'many',
#  'things',
#  'and',
#  'people',
#  'around',
#  'that',
#  'makes',
#  'sense',
#  'honestly',
#  'just',
#  'looking',
#  'for',
#  'something',
#  'pass',
#  'the',
#  'time',
#  'like',
#  'well',
#  'there',
#  'bicycle',
#  'wanted',
#  'more',
#  'than',
#  'anything',
#  'when',
#  'remember',
#  'this',
#  'story',
#  'vaguely',
#  'happened',
#  'got',
#  'science',
#  'kit',
#  'my',
#  'birthday',
#  'crappy',
#  'ones',
#  'can',
#  'buy',
#  'toy',
#  'shop',
#  'yes',
#  'but',
#  'did',
#  'collected',
#  'same',
#  'chemical',
#  'over',
#  'again',
#  'from',
#  'pharmacies',
#  'enough',
#  'make',
#  'explosion',
#  'enormous',
#  '…',
#  'blew',
#  'roof',
#  'off',
#  'house',
#  'hole',
#  '-',
#  'parents',
#  'were',
#  'poor',
#  'we',
#  'lived',
#  'with',
#  'our',
#  'months',
#  'say',
#  'they',
#  'both',
#  'angry',
#  'had',
#  'lot',
#  'love',
#  'me',
#  'fine',
#  'end',
#  'winter',
#  'thankfully',
#  'not',
#  'quite',
#  'cold',
#  'though',
#  'at',
#  'times',
#  'do',
#  'back',
#  'those',
#  'very',
#  'fondly',
#  'however',
#  'life',
#  'simple',
#  'maybe',
#  'that’s',
#  'how',
#  'no',
#  'yep',
#  'everything',
#  'being',
#  'much',
#  'easier',
#  'wake',
#  'watch',
#  'cartoons',
#  'on',
#  'saturday',
#  'pancakes',
#  'smell',
#  'most',
#  'feeling',
#  'warm',
#  'sun',
#  'coming',
#  'through',
#  'windows',
#  'all',
#  'plants',
#  'have',
#  'course',
#  'important',
#  'grow',
#  'really',
#  'why',
#  'i’m',
#  'entirely',
#  'sure',
#  'because',
#  'younger',
#  'struggle',
#  'accept',
#  'big',
#  'disposal',
#  'including',
#  'middle',
#  'class',
#  'family',
#  'nothing',
#  'handed',
#  'feel',
#  'such',
#  'an',
#  'integral',
#  'part',
#  'education',
#  'fend',
#  'myself',
#  'assumed',
#  'learn',
#  'stuff',
#  'too',
#  'young',
#  'age',
#  'mean',
#  'it’s',
#  'force',
#  'go',
#  'out',
#  'shops',
#  'dark',
#  'or',
#  'getting',
#  'motorbike',
#  'scary',
#  'yeah',
#  'best',
#  'move',
#  'be',
#  '‘streetwise’',
#  'ten',
#  'years',
#  'old',
#  'would',
#  'come',
#  'naturally',
#  'sorry…',
#  'these',
#  'didn’t',
#  'sometimes',
#  'ok',
#  'now',
#  'glad',
#  'father',
#  'loved',
#  'him',
#  'difficult',
#  'said',
#  'tried',
#  'better',
#  'holidays',
#  'food',
#  'etc…',
#  'doesn’t',
#  'less',
#  'surely',
#  'oh',
#  'completely',
#  'even',
#  'understand',
#  'effort',
#  'he',
#  'put',
#  'into',
#  'making',
#  'communist',
#  'wasn’t',
#  'party',
#  'while',
#  'grew',
#  'socialist',
#  'giving',
#  'if',
#  'needed',
#  'lacking',
#  'today',
#  'grandpa',
#  'bring',
#  'home',
#  'homeless',
#  'drive',
#  'grandma',
#  'insane',
#  'honest',
#  'caring',
#  'am',
#  'others',
#  'trustworthy',
#  'grandma’s',
#  'side',
#  'incident…',
#  'incident',
#  'basically',
#  'brought',
#  'guy',
#  'sleep',
#  'bare',
#  'mind',
#  'space',
#  'uncle',
#  'yeah…',
#  'anyways',
#  'gone',
#  'unusual',
#  'he’s',
#  'spent',
#  'night',
#  'right',
#  'bathroom',
#  'literally',
#  'smeared',
#  'shit',
#  'walls',
#  'clean',
#  'up…',
#  'man…',
#  'rough',
#  'courage',
#  'trust',
#  'wrath',
#  'sad',
#  'knew',
#  'yet',
#  'still',
#  'miss',
#  'god',
#  'sister',
#  'few',
#  'clear',
#  'memories',
#  'chateau',
#  'lignan',
#  'where',
#  'holiday',
#  'south',
#  'france',
#  'some',
#  'visit',
#  'us',
#  'lola',
#  'presents',
#  'snotty',
#  'stupid',
#  'appreciating',
#  'his',
#  'gifts',
#  'smile',
#  'thank',
#  'nice',
#  'inside',
#  'thinking',
#  'colouring',
#  'books',
#  'pencils',
#  'etc',
#  'touch',
#  'guys',
#  'money',
#  'spend',
#  'cried',
#  'see',
#  'beautiful',
#  'gesture',
#  'amazing',
#  'man',
#  'was…',
#  'wear',
#  'gold',
#  'chain',
#  'gifted',
#  'once',
#  'wait',
#  'actually',
#  'subject',
#  'enjoyed',
#  'then',
#  'length',
#  'other',
#  "wouldn't",
#  'whereas',
#  'grandmother',
#  "it's",
#  'she',
#  'likes',
#  "don't",
#  "she'd",
#  'idea',
#  'kind',
#  'wish',
#  'fault',
#  'thin',
#  'guitar',
#  'pendant',
#  'recently',
#  'found',
#  'year',
#  'ago',
#  'take',
#  'seeing',
#  'neck',
#  'taking',
#  'piss',
#  'look',
#  'gangster',
#  'grandpas',
#  'took',
#  'comes',
#  'sweet',
#  'bet',
#  'happy',
#  'hear',
#  'hope',
#  'regret',
#  'bought',
#  'new',
#  'dog',
#  'certainly',
#  'emotional',
#  'respected',
#  'older',
#  'respect',
#  'tap',
#  'their',
#  'emotions',
#  'we’re',
#  'talking—',
#  'minute',
#  'okay',
#  'son',
#  'please',
#  'does',
#  'moment',
#  'i…',
#  'nope',
#  'can’t',
#  'wait…what',
#  'like…ten',
#  'sat',
#  'down',
#  'seven',
#  'math',
#  'tutor',
#  'worth',
#  '“ahem',
#  'uh…listen',
#  'want',
#  'differently…if',
#  'ever',
#  'begin',
#  '‘because',
#  'so’',
#  'gotta',
#  'slap',
#  'remind',
#  'hated',
#  'hearing',
#  'up”',
#  'voice…that',
#  'supposed',
#  'sound',
#  'seriously',
#  'serious',
#  'need',
#  'it…now',
#  'soon',
#  'mother',
#  'will',
#  'here',
#  'any',
#  'problem',
#  'because…',
#  'c’mon',
#  'you’re',
#  'almost',
#  'grown',
#  'start',
#  'taking…',
#  'care',
#  'mom',
#  'are',
#  'ready',
#  'already',
#  'finished',
#  'coll–',
#  'save',
#  'whoa',
#  'what’s',
#  'i’ll',
#  'mean…jesus',
#  'matter',
#  'guess',
#  'you’ll…',
#  'shit…lemme',
#  'uhwasn’t',
#  'going',
#  'just…please',
#  'she’ll',
#  'afraid',
#  'her',
#  '‘have',
#  'her’',
#  'fuck',
#  'nerve',
#  'to…',
#  'college',
#  'changing',
#  'ways',
#  'expect',
#  'i’',
#  'm',
#  'sorry',
#  'was…out',
#  'line',
#  'i’m…sorry',
#  'fo',
#  'deserved',
#  'defnitely',
#  'i’d…actually',
#  'disagree',
#  'made',
#  'who',
#  'dads',
#  'top',
#  'parenting',
#  'resume',
#  'deal',
#  'spanked',
#  'kids',
#  'acted',
#  'meant',
#  'well…mine',
#  'uh-huh',
#  'here’s',
#  'thing',
#  'test',
#  'two',
#  'seconds',
#  'least',
#  'they’re',
#  'certain',
#  'set',
#  '‘em',
#  'straight',
#  'sit',
#  'bookshelf',
#  'lemme',
#  'just…here',
#  'ya',
#  'thanks',
#  'huh',
#  'comfy',
#  'woulda',
#  'imagined',
#  'worn',
#  'past',
#  'roommate',
#  'i’d',
#  'god’s',
#  'sake…i',
#  'them',
#  'couple',
#  'nights',
#  'before',
#  'went',
#  'must',
#  'next',
#  'bed',
#  'um…',
#  'chair',
#  'asked',
#  'coffee',
#  'that’d',
#  'nice…except',
#  'came',
#  'first',
#  'place',
#  'willing',
#  'remarkable',
#  'ha',
#  'guilty',
#  'know…your',
#  'whatever',
#  'rush',
#  'kiddin’',
#  'gettin’',
#  'let',
#  'ugh…she',
#  'takes',
#  'wrong',
#  'son…she’s',
#  'cares',
#  'only',
#  'tells',
#  'suggesting',
#  'open',
#  'dick',
#  'gonna',
#  'prefer',
#  'bed…for',
#  'obvious',
#  'reasons',
#  'meantime',
#  'exhibit',
#  'heard',
#  'earlier',
#  'okay…dad',
#  'why’d',
#  'happen',
#  'forgot',
#  'couldn’t',
#  'finish',
#  'last',
#  'she’s',
#  'second',
#  'we’ll',
#  'sopping',
#  'beer',
#  'carpet',
#  'dammit',
#  'imports',
#  'cleaning',
#  'liked',
#  'fancy',
#  'beers',
#  'splurge',
#  'thought',
#  'drink',
#  'forget',
#  'nineteen',
#  'impossible',
#  'room’s',
#  'there’s',
#  'triple-pissed',
#  'fun',
#  'weekend',
#  'relax',
#  'shut',
#  'crouched',
#  'fucking',
#  'floor',
#  'goddammit',
#  'tense',
#  'here…sort',
#  'fall',
#  'beanbag',
#  'you…',
#  'rubbed',
#  'against',
#  'she’d',
#  'saying',
#  'torture',
#  'any…pills',
#  'my…i',
#  'mean…wait',
#  'uhput',
#  'them…',
#  'yelling',
#  'isn’t',
#  'speed',
#  'memory',
#  'seen',
#  'nightstand',
#  'just…breathe…',
#  'baby',
#  'mean…relax',
#  'check',
#  'aren’t',
#  'find',
#  'jesus',
#  'either',
#  'gimme',
#  'water',
#  'bottle’s',
#  'empty',
#  'bottle',
#  'filled',
#  'it…lemme',
#  'see…when',
#  'go…',
#  'says',
#  'refill',
#  'allowed',
#  'doctor’s',
#  'approval',
#  'until',
#  'monday',
#  'lay',
#  'face',
#  'in…ugh…whatever’s',
#  'fucked',
#  'kidding',
#  'door',
#  "i'm",
#  'law',
#  'school',
#  'called',
#  'congratulations',
#  "you'll",
#  'supreme',
#  'court',
#  'may',
#  'chase',
#  'ambulances',
#  "how's",
#  'raymond',
#  "he's",
#  'ocs',
#  'army',
#  "that's",
#  'bad',
#  "haven't",
#  'jennifer',
#  "she's",
#  'absolutely',
#  'charming',
#  'background',
#  'radcliffe',
#  'point',
#  "doesn't",
#  'concern',
#  'rebellion',
#  'rebelling',
#  'fail',
#  'marrying',
#  'brilliant',
#  'girl',
#  'constitutes',
#  'crazy',
#  'hippie',
#  'irks',
#  'catholic',
#  'attracts',
#  'leaving',
#  'half-cocked',
#  'ask',
#  'define',
#  '"bit"',
#  'real',
#  "it'll",
#  'stand',
#  'should',
#  'asking',
#  "you're",
#  'commanding',
#  'marry',
#  "i'll",
#  'give',
#  'day',
#  'know…',
#  'saving',
#  'cycling',
#  'sport',
#  'interested',
#  'bored',
#  'eventually',
#  'stay',
#  'selfish',
#  'known',
#  'born',
#  'doing',
#  'extent',
#  'harder',
#  'especially',
#  'after',
#  'divorce',
#  'really…',
#  'changed',
#  'became',
#  'felt',
#  'suddenly',
#  'fair',
#  'talked',
#  'mum',
#  'happening',
#  'react',
#  'do…',
#  'creating',
#  'sides',
#  'pick',
#  'tell',
#  'which',
#  'clearly',
#  'untrue',
#  'head',
#  'smoked',
#  'cigarettes',
#  'impressionable',
#  'saw',
#  'horrible',
#  'stressed',
#  'die',
#  'brining',
#  'conversation',
#  'holding',
#  'grudges',
#  'deep',
#  'subconscious',
#  'badly',
#  'thankful',
#  'arguments',
#  '16',
#  'damn',
#  'along',
#  'experience',
#  'raising',
#  'teenager',
#  'thicker',
#  'skin',
#  'also',
#  'clashing',
#  'personalities',
#  'similar',
#  'obsessive',
#  'nature',
#  'obsess',
#  'needs',
#  'internally',
#  'freak',
#  'slight',
#  'ocd',
#  'twice',
#  'hoovering',
#  '8am',
#  'compulsive',
#  'keeping',
#  'commend',
#  'taught',
#  'bother',
#  'example',
#  'you’d',
#  'nuts',
#  'walked',
#  'feet',
#  'slippers',
#  'everywhere',
#  'special',
#  'white',
#  'resin',
#  'dirty',
#  'super',
#  'fast',
#  'consisted',
#  'listening',
#  'tail',
#  'between',
#  'legs',
#  'hit',
#  'sixteen',
#  'own',
#  'clashed',
#  'anymore',
#  'silly',
#  'started',
#  'general…',
#  'vegetables',
#  'lucas',
#  'on…',
#  'obsession',
#  'bothered',
#  'health',
#  'ate',
#  'plate',
#  'salad',
#  'tomatoes',
#  'eat',
#  'could',
#  'complain',
#  'petty',
#  'scared',
#  'mean…',
#  'otherwise',
#  'pissed',
#  'off…',
#  'phones',
#  'obsessed',
#  'constantly',
#  'phone',
#  'again…',
#  'weren’t',
#  'decent',
#  'amount',
#  'ipod',
#  'everyone',
#  'definitely',
#  'diego',
#  'jealous…',
#  'christmas',
#  'gift',
#  'playing',
#  'hours',
#  'spending',
#  'devices',
#  'whole',
#  'world',
#  'able',
#  'download',
#  'games',
#  'understood',
#  'gaming',
#  'attractive',
#  'small',
#  'screen',
#  'console',
#  'true',
#  'nintendo',
#  'ds',
#  'life…',
#  'tiger',
#  'imagining',
#  'try',
#  'cute',
#  'wanting',
#  'pre-naughties',
#  'present',
#  'asks',
#  'bicycles',
#  'bike',
#  'mario',
#  'kart',
#  'trying',
#  'exciting',
#  'interest',
#  'died',
#  'kept',
#  'pestering',
#  'every',
#  'single',
#  'text',
#  'annoyed',
#  'reason',
#  'overbearing',
#  'technology',
#  'tiny',
#  'told',
#  'surprise',
#  'bus',
#  'shopping',
#  'centre',
#  'starting',
#  'music',
#  'cool',
#  'collect',
#  'angsty',
#  'rock',
#  'stage',
#  'black',
#  'skinny',
#  'jeans',
#  'phase',
#  'else',
#  'truly',
#  'believed',
#  'jeans…',
#  'goodness',
#  'grunge',
#  'truthfully',
#  'goes',
#  'yours',
#  'brother',
#  '‘group’',
#  'belong',
#  'group',
#  'friends',
#  'pj',
#  'max',
#  'played',
#  'sounds',
#  'right…',
#  'electric',
#  'lesson',
#  'shame',
#  'cello',
#  'plus',
#  'forced',
#  'play',
#  'appreciate',
#  'skateboarding',
#  'talking',
#  'tricks',
#  'lessons',
#  'hundreds',
#  'ended',
#  'of…',
#  'computer',
#  'geeky',
#  'opposite',
#  'proud',
#  'help',
#  'self',
#  'generation',
#  'use',
#  'correctly',
#  'period',
#  'normally',
#  'suppose',
#  'experiences…',
#  'spoke',
#  'surprised',
#  'opinion',
#  'hard',
#  'interesting',
#  'converse',
#  'degree',
#  'interaction',
#  'view',
#  'differences',
#  'men',
#  'women',
#  'shout',
#  'choose',
#  'ignore',
#  'worse',
#  ...]

# %%
datasetDictionary
# Out:
# Counter({'hey': 2,
#          'dad': 13,
#          "let's": 1,
#          'talk': 7,
#          'about': 19,
#          'your': 42,
#          'childhood': 2,
#          'i’ve': 3,
#          'always': 13,
#          'been': 7,
#          'curious': 1,
#          'you': 184,
#          'know': 50,
#          'i': 304,
#          'was': 98,
#          'never': 23,
#          'as': 19,
#          'good': 7,
#          'of': 63,
#          'a': 92,
#          'kid': 9,
#          'you’ve': 4,
#          'mentioned': 2,
#          'think': 26,
#          'it': 98,
#          'different': 3,
#          'growing': 5,
#          'up': 18,
#          'in': 38,
#          'smaller': 1,
#          'city': 2,
#          'probably': 6,
#          'london': 2,
#          'is': 16,
#          'bit': 5,
#          'weird': 2,
#          'one': 18,
#          'what': 55,
#          'way': 11,
#          'don’t': 15,
#          'sort': 6,
#          'get': 28,
#          'used': 10,
#          'to': 123,
#          'having': 4,
#          'so': 38,
#          'many': 2,
#          'things': 14,
#          'and': 80,
#          'people': 6,
#          'around': 5,
#          'that': 101,
#          'makes': 2,
#          'sense': 3,
#          'honestly': 10,
#          'just': 39,
#          'looking': 2,
#          'for': 35,
#          'something': 8,
#          'pass': 1,
#          'the': 91,
#          'time': 21,
#          'like': 34,
#          'well': 25,
#          'there': 11,
#          'bicycle': 1,
#          'wanted': 15,
#          'more': 13,
#          'than': 6,
#          'anything': 5,
#          'when': 28,
#          'remember': 29,
#          'this': 28,
#          'story': 3,
#          'vaguely': 1,
#          'happened': 1,
#          'got': 21,
#          'science': 1,
#          'kit': 1,
#          'my': 42,
#          'birthday': 2,
#          'crappy': 1,
#          'ones': 1,
#          'can': 6,
#          'buy': 2,
#          'toy': 2,
#          'shop': 1,
#          'yes': 30,
#          'but': 55,
#          'did': 20,
#          'collected': 1,
#          'same': 5,
#          'chemical': 1,
#          'over': 5,
#          'again': 2,
#          'from': 13,
#          'pharmacies': 1,
#          'enough': 1,
#          'make': 6,
#          'explosion': 1,
#          'enormous': 1,
#          '…': 1,
#          'blew': 1,
#          'roof': 2,
#          'off': 11,
#          'house': 5,
#          'hole': 2,
#          '-': 4,
#          'parents': 3,
#          'were': 28,
#          'poor': 3,
#          'we': 24,
#          'lived': 1,
#          'with': 29,
#          'our': 6,
#          'months': 2,
#          'say': 12,
#          'they': 9,
#          'both': 6,
#          'angry': 3,
#          'had': 18,
#          'lot': 7,
#          'love': 5,
#          'me': 43,
#          'fine': 9,
#          'end': 1,
#          'winter': 1,
#          'thankfully': 1,
#          'not': 33,
#          'quite': 5,
#          'cold': 1,
#          'though': 11,
#          'at': 23,
#          'times': 4,
#          'do': 44,
#          'back': 6,
#          'those': 9,
#          'very': 5,
#          'fondly': 1,
#          'however': 2,
#          'life': 7,
#          'simple': 2,
#          'maybe': 4,
#          'that’s': 24,
#          'how': 14,
#          'no': 18,
#          'yep': 3,
#          'everything': 9,
#          'being': 4,
#          'much': 10,
#          'easier': 2,
#          'wake': 2,
#          'watch': 2,
#          'cartoons': 2,
#          'on': 27,
#          'saturday': 2,
#          'pancakes': 1,
#          'smell': 1,
#          'most': 7,
#          'feeling': 1,
#          'warm': 2,
#          'sun': 1,
#          'coming': 1,
#          'through': 4,
#          'windows': 1,
#          'all': 18,
#          'plants': 2,
#          'have': 28,
#          'course': 2,
#          'important': 1,
#          'grow': 2,
#          'really': 38,
#          'why': 8,
#          'i’m': 31,
#          'entirely': 1,
#          'sure': 13,
#          'because': 15,
#          'younger': 7,
#          'struggle': 1,
#          'accept': 2,
#          'big': 3,
#          'disposal': 1,
#          'including': 1,
#          'middle': 1,
#          'class': 1,
#          'family': 2,
#          'nothing': 3,
#          'handed': 1,
#          'feel': 6,
#          'such': 6,
#          'an': 7,
#          'integral': 1,
#          'part': 5,
#          'education': 1,
#          'fend': 1,
#          'myself': 3,
#          'assumed': 1,
#          'learn': 1,
#          'stuff': 10,
#          'too': 15,
#          'young': 5,
#          'age': 4,
#          'mean': 27,
#          'it’s': 20,
#          'force': 1,
#          'go': 9,
#          'out': 6,
#          'shops': 2,
#          'dark': 1,
#          'or': 14,
#          'getting': 6,
#          'motorbike': 1,
#          'scary': 1,
#          'yeah': 26,
#          'best': 3,
#          'move': 1,
#          'be': 30,
#          '‘streetwise’': 1,
#          'ten': 2,
#          'years': 2,
#          'old': 3,
#          'would': 24,
#          'come': 5,
#          'naturally': 1,
#          'sorry…': 1,
#          'these': 1,
#          'didn’t': 18,
#          'sometimes': 6,
#          'ok': 8,
#          'now': 21,
#          'glad': 3,
#          'father': 3,
#          'loved': 3,
#          'him': 12,
#          'difficult': 6,
#          'said': 8,
#          'tried': 2,
#          'better': 6,
#          'holidays': 2,
#          'food': 1,
#          'etc…': 1,
#          'doesn’t': 2,
#          'less': 1,
#          'surely': 1,
#          'oh': 18,
#          'completely': 2,
#          'even': 9,
#          'understand': 3,
#          'effort': 1,
#          'he': 22,
#          'put': 3,
#          'into': 10,
#          'making': 1,
#          'communist': 2,
#          'wasn’t': 8,
#          'party': 1,
#          'while': 4,
#          'grew': 1,
#          'socialist': 1,
#          'giving': 2,
#          'if': 14,
#          'needed': 4,
#          'lacking': 1,
#          'today': 1,
#          'grandpa': 5,
#          'bring': 2,
#          'home': 3,
#          'homeless': 2,
#          'drive': 1,
#          'grandma': 3,
#          'insane': 1,
#          'honest': 2,
#          'caring': 1,
#          'am': 4,
#          'others': 1,
#          'trustworthy': 1,
#          'grandma’s': 1,
#          'side': 2,
#          'incident…': 1,
#          'incident': 1,
#          'basically': 4,
#          'brought': 1,
#          'guy': 3,
#          'sleep': 2,
#          'bare': 2,
#          'mind': 2,
#          'space': 1,
#          'uncle': 1,
#          'yeah…': 1,
#          'anyways': 5,
#          'gone': 1,
#          'unusual': 1,
#          'he’s': 1,
#          'spent': 1,
#          'night': 3,
#          'right': 7,
#          'bathroom': 2,
#          'literally': 6,
#          'smeared': 1,
#          'shit': 8,
#          'walls': 1,
#          'clean': 4,
#          'up…': 1,
#          'man…': 1,
#          'rough': 1,
#          'courage': 2,
#          'trust': 3,
#          'wrath': 1,
#          'sad': 1,
#          'knew': 2,
#          'yet': 1,
#          'still': 4,
#          'miss': 1,
#          'god': 3,
#          'sister': 4,
#          'few': 1,
#          'clear': 1,
#          'memories': 1,
#          'chateau': 1,
#          'lignan': 1,
#          'where': 4,
#          'holiday': 2,
#          'south': 1,
#          'france': 1,
#          'some': 9,
#          'visit': 1,
#          'us': 1,
#          'lola': 2,
#          'presents': 1,
#          'snotty': 1,
#          'stupid': 1,
#          'appreciating': 1,
#          'his': 2,
#          'gifts': 2,
#          'smile': 1,
#          'thank': 2,
#          'nice': 1,
#          'inside': 1,
#          'thinking': 2,
#          'colouring': 1,
#          'books': 1,
#          'pencils': 1,
#          'etc': 3,
#          'touch': 3,
#          'guys': 2,
#          'money': 2,
#          'spend': 1,
#          'cried': 2,
#          'see': 5,
#          'beautiful': 2,
#          'gesture': 1,
#          'amazing': 3,
#          'man': 8,
#          'was…': 1,
#          'wear': 3,
#          'gold': 3,
#          'chain': 3,
#          'gifted': 3,
#          'once': 2,
#          'wait': 5,
#          'actually': 3,
#          'subject': 1,
#          'enjoyed': 1,
#          'then': 10,
#          'length': 1,
#          'other': 1,
#          "wouldn't": 3,
#          'whereas': 1,
#          'grandmother': 1,
#          "it's": 3,
#          'she': 10,
#          'likes': 2,
#          "don't": 6,
#          "she'd": 1,
#          'idea': 2,
#          'kind': 3,
#          'wish': 2,
#          'fault': 2,
#          'thin': 1,
#          'guitar': 5,
#          'pendant': 2,
#          'recently': 1,
#          'found': 2,
#          'year': 6,
#          'ago': 4,
#          'take': 2,
#          'seeing': 1,
#          'neck': 2,
#          'taking': 1,
#          'piss': 3,
#          'look': 8,
#          'gangster': 1,
#          'grandpas': 1,
#          'took': 4,
#          'comes': 2,
#          'sweet': 1,
#          'bet': 2,
#          'happy': 5,
#          'hear': 7,
#          'hope': 1,
#          'regret': 3,
#          'bought': 2,
#          'new': 6,
#          'dog': 1,
#          'certainly': 1,
#          'emotional': 1,
#          'respected': 1,
#          'older': 2,
#          'respect': 1,
#          'tap': 1,
#          'their': 3,
#          'emotions': 1,
#          'we’re': 5,
#          'talking—': 1,
#          'minute': 1,
#          'okay': 10,
#          'son': 7,
#          'please': 2,
#          'does': 4,
#          'moment': 1,
#          'i…': 1,
#          'nope': 1,
#          'can’t': 4,
#          'wait…what': 1,
#          'like…ten': 1,
#          'sat': 1,
#          'down': 4,
#          'seven': 1,
#          'math': 1,
#          'tutor': 1,
#          'worth': 2,
#          '“ahem': 1,
#          'uh…listen': 1,
#          'want': 9,
#          'differently…if': 1,
#          'ever': 6,
#          'begin': 2,
#          '‘because': 1,
#          'so’': 1,
#          'gotta': 3,
#          'slap': 1,
#          'remind': 1,
#          'hated': 2,
#          'hearing': 1,
#          'up”': 1,
#          'voice…that': 1,
#          'supposed': 1,
#          'sound': 1,
#          'seriously': 1,
#          'serious': 1,
#          'need': 2,
#          'it…now': 1,
#          'soon': 2,
#          'mother': 5,
#          'will': 2,
#          'here': 5,
#          'any': 8,
#          'problem': 1,
#          'because…': 1,
#          'c’mon': 1,
#          'you’re': 4,
#          'almost': 2,
#          'grown': 2,
#          'start': 1,
#          'taking…': 1,
#          'care': 1,
#          'mom': 2,
#          'are': 6,
#          'ready': 1,
#          'already': 2,
#          'finished': 1,
#          'coll–': 1,
#          'save': 1,
#          'whoa': 1,
#          'what’s': 6,
#          'i’ll': 6,
#          'mean…jesus': 1,
#          'matter': 1,
#          'guess': 8,
#          'you’ll…': 1,
#          'shit…lemme': 1,
#          'uhwasn’t': 1,
#          'going': 8,
#          'just…please': 1,
#          'she’ll': 1,
#          'afraid': 2,
#          'her': 12,
#          '‘have': 1,
#          'her’': 1,
#          'fuck': 2,
#          'nerve': 1,
#          'to…': 1,
#          'college': 1,
#          'changing': 1,
#          'ways': 1,
#          'expect': 1,
#          'i’': 1,
#          'm': 1,
#          'sorry': 8,
#          'was…out': 1,
#          'line': 1,
#          'i’m…sorry': 1,
#          'fo': 1,
#          'deserved': 1,
#          'defnitely': 1,
#          'i’d…actually': 1,
#          'disagree': 1,
#          'made': 1,
#          'who': 4,
#          'dads': 2,
#          'top': 1,
#          'parenting': 1,
#          'resume': 1,
#          'deal': 2,
#          'spanked': 1,
#          'kids': 3,
#          'acted': 1,
#          'meant': 1,
#          'well…mine': 1,
#          'uh-huh': 1,
#          'here’s': 1,
#          'thing': 9,
#          'test': 3,
#          'two': 2,
#          'seconds': 1,
#          'least': 2,
#          'they’re': 1,
#          'certain': 4,
#          'set': 1,
#          '‘em': 1,
#          'straight': 1,
#          'sit': 2,
#          'bookshelf': 1,
#          'lemme': 3,
#          'just…here': 1,
#          'ya': 1,
#          'thanks': 1,
#          'huh': 3,
#          'comfy': 1,
#          'woulda': 1,
#          'imagined': 1,
#          'worn': 1,
#          'past': 2,
#          'roommate': 1,
#          'i’d': 2,
#          'god’s': 1,
#          'sake…i': 1,
#          'them': 7,
#          'couple': 1,
#          'nights': 1,
#          'before': 1,
#          'went': 1,
#          'must': 2,
#          'next': 2,
#          'bed': 2,
#          'um…': 1,
#          'chair': 2,
#          'asked': 2,
#          'coffee': 1,
#          'that’d': 1,
#          'nice…except': 1,
#          'came': 1,
#          'first': 6,
#          'place': 3,
#          'willing': 1,
#          'remarkable': 1,
#          'ha': 2,
#          'guilty': 1,
#          'know…your': 1,
#          'whatever': 2,
#          'rush': 1,
#          'kiddin’': 1,
#          'gettin’': 1,
#          'let': 3,
#          'ugh…she': 1,
#          'takes': 1,
#          'wrong': 2,
#          'son…she’s': 1,
#          'cares': 1,
#          'only': 4,
#          'tells': 1,
#          'suggesting': 1,
#          'open': 1,
#          'dick': 1,
#          'gonna': 1,
#          'prefer': 1,
#          'bed…for': 1,
#          'obvious': 1,
#          'reasons': 1,
#          'meantime': 1,
#          'exhibit': 1,
#          'heard': 1,
#          'earlier': 1,
#          'okay…dad': 1,
#          'why’d': 1,
#          'happen': 1,
#          'forgot': 2,
#          'couldn’t': 3,
#          'finish': 2,
#          'last': 2,
#          'she’s': 2,
#          'second': 2,
#          'we’ll': 1,
#          'sopping': 1,
#          'beer': 2,
#          'carpet': 2,
#          'dammit': 1,
#          'imports': 1,
#          'cleaning': 2,
#          'liked': 3,
#          'fancy': 1,
#          'beers': 1,
#          'splurge': 1,
#          'thought': 2,
#          'drink': 1,
#          'forget': 1,
#          'nineteen': 1,
#          'impossible': 1,
#          'room’s': 1,
#          'there’s': 1,
#          'triple-pissed': 1,
#          'fun': 3,
#          'weekend': 1,
#          'relax': 1,
#          'shut': 1,
#          'crouched': 1,
#          'fucking': 2,
#          'floor': 5,
#          'goddammit': 1,
#          'tense': 1,
#          'here…sort': 1,
#          'fall': 1,
#          'beanbag': 2,
#          'you…': 2,
#          'rubbed': 1,
#          'against': 2,
#          'she’d': 1,
#          'saying': 2,
#          'torture': 1,
#          'any…pills': 1,
#          'my…i': 1,
#          'mean…wait': 1,
#          'uhput': 1,
#          'them…': 1,
#          'yelling': 1,
#          'isn’t': 1,
#          'speed': 1,
#          'memory': 1,
#          'seen': 1,
#          'nightstand': 1,
#          'just…breathe…': 1,
#          'baby': 1,
#          'mean…relax': 1,
#          'check': 1,
#          'aren’t': 1,
#          'find': 2,
#          'jesus': 1,
#          'either': 1,
#          'gimme': 1,
#          'water': 1,
#          'bottle’s': 1,
#          'empty': 2,
#          'bottle': 1,
#          'filled': 2,
#          'it…lemme': 1,
#          'see…when': 1,
#          'go…': 1,
#          'says': 1,
#          'refill': 1,
#          'allowed': 2,
#          'doctor’s': 1,
#          'approval': 1,
#          'until': 2,
#          'monday': 2,
#          'lay': 1,
#          'face': 1,
#          'in…ugh…whatever’s': 1,
#          'fucked': 2,
#          'kidding': 1,
#          'door': 1,
#          "i'm": 3,
#          'law': 2,
#          'school': 4,
#          'called': 1,
#          'congratulations': 1,
#          "you'll": 1,
#          'supreme': 1,
#          'court': 1,
#          'may': 2,
#          'chase': 1,
#          'ambulances': 1,
#          "how's": 1,
#          'raymond': 1,
#          "he's": 1,
#          'ocs': 1,
#          'army': 1,
#          "that's": 4,
#          'bad': 3,
#          "haven't": 1,
#          'jennifer': 1,
#          "she's": 5,
#          'absolutely': 1,
#          'charming': 1,
#          'background': 1,
#          'radcliffe': 2,
#          'point': 2,
#          "doesn't": 1,
#          'concern': 1,
#          'rebellion': 2,
#          'rebelling': 2,
#          'fail': 2,
#          'marrying': 1,
#          'brilliant': 1,
#          'girl': 1,
#          'constitutes': 1,
#          'crazy': 2,
#          'hippie': 1,
#          'irks': 1,
#          'catholic': 1,
#          'attracts': 1,
#          'leaving': 2,
#          'half-cocked': 1,
#          'ask': 3,
#          'define': 1,
#          '"bit"': 1,
#          'real': 2,
#          "it'll": 1,
#          'stand': 1,
#          'should': 1,
#          'asking': 1,
#          "you're": 1,
#          'commanding': 1,
#          'marry': 1,
#          "i'll": 1,
#          'give': 1,
#          'day': 5,
#          'know…': 2,
#          'saving': 1,
#          'cycling': 1,
#          'sport': 1,
#          'interested': 1,
#          'bored': 3,
#          'eventually': 2,
#          'stay': 1,
#          'selfish': 1,
#          'known': 2,
#          'born': 1,
#          'doing': 2,
#          'extent': 1,
#          'harder': 1,
#          'especially': 2,
#          'after': 2,
#          'divorce': 1,
#          'really…': 1,
#          'changed': 1,
#          'became': 1,
#          'felt': 6,
#          'suddenly': 1,
#          'fair': 2,
#          'talked': 1,
#          'mum': 7,
#          'happening': 1,
#          'react': 1,
#          'do…': 1,
#          'creating': 1,
#          'sides': 1,
#          'pick': 2,
#          'tell': 5,
#          'which': 2,
#          'clearly': 4,
#          'untrue': 1,
#          'head': 3,
#          'smoked': 1,
#          'cigarettes': 1,
#          'impressionable': 1,
#          'saw': 1,
#          'horrible': 1,
#          'stressed': 1,
#          'die': 1,
#          'brining': 1,
#          'conversation': 3,
#          'holding': 1,
#          'grudges': 1,
#          'deep': 1,
#          'subconscious': 1,
#          'badly': 2,
#          'thankful': 1,
#          'arguments': 1,
#          '16': 1,
#          'damn': 7,
#          'along': 1,
#          'experience': 1,
#          'raising': 1,
#          'teenager': 1,
#          'thicker': 1,
#          'skin': 1,
#          'also': 3,
#          'clashing': 2,
#          'personalities': 1,
#          'similar': 2,
#          'obsessive': 3,
#          'nature': 2,
#          'obsess': 1,
#          'needs': 1,
#          'internally': 1,
#          'freak': 1,
#          'slight': 1,
#          'ocd': 2,
#          'twice': 1,
#          'hoovering': 1,
#          '8am': 1,
#          'compulsive': 1,
#          'keeping': 1,
#          'commend': 1,
#          'taught': 2,
#          'bother': 1,
#          'example': 2,
#          'you’d': 2,
#          'nuts': 1,
#          'walked': 1,
#          'feet': 1,
#          'slippers': 1,
#          'everywhere': 1,
#          'special': 1,
#          'white': 1,
#          'resin': 1,
#          'dirty': 1,
#          'super': 1,
#          'fast': 1,
#          'consisted': 1,
#          'listening': 1,
#          'tail': 1,
#          'between': 2,
#          'legs': 1,
#          'hit': 1,
#          'sixteen': 2,
#          'own': 1,
#          'clashed': 1,
#          'anymore': 2,
#          'silly': 1,
#          'started': 3,
#          'general…': 1,
#          'vegetables': 3,
#          'lucas': 1,
#          'on…': 1,
#          'obsession': 1,
#          'bothered': 1,
#          'health': 2,
#          'ate': 2,
#          'plate': 1,
#          'salad': 2,
#          'tomatoes': 2,
#          'eat': 2,
#          'could': 3,
#          'complain': 1,
#          'petty': 1,
#          'scared': 1,
#          'mean…': 1,
#          'otherwise': 1,
#          'pissed': 1,
#          'off…': 1,
#          'phones': 3,
#          'obsessed': 2,
#          'constantly': 2,
#          'phone': 3,
#          'again…': 1,
#          'weren’t': 1,
#          'decent': 1,
#          'amount': 1,
#          'ipod': 3,
#          'everyone': 1,
#          'definitely': 2,
#          'diego': 1,
#          'jealous…': 1,
#          'christmas': 5,
#          'gift': 1,
#          'playing': 2,
#          'hours': 1,
#          'spending': 1,
#          'devices': 1,
#          'whole': 2,
#          'world': 1,
#          'able': 1,
#          'download': 1,
#          'games': 1,
#          'understood': 2,
#          'gaming': 2,
#          'attractive': 1,
#          'small': 1,
#          'screen': 1,
#          'console': 2,
#          'true': 5,
#          'nintendo': 2,
#          'ds': 2,
#          'life…': 1,
#          'tiger': 1,
#          'imagining': 1,
#          'try': 2,
#          'cute': 1,
#          'wanting': 3,
#          'pre-naughties': 1,
#          'present': 1,
#          'asks': 1,
#          'bicycles': 1,
#          'bike': 1,
#          'mario': 1,
#          'kart': 1,
#          'trying': 2,
#          'exciting': 1,
#          'interest': 1,
#          'died': 1,
#          'kept': 1,
#          'pestering': 1,
#          'every': 4,
#          'single': 2,
#          'text': 4,
#          'annoyed': 1,
#          'reason': 1,
#          'overbearing': 1,
#          'technology': 1,
#          'tiny': 1,
#          'told': 3,
#          'surprise': 1,
#          'bus': 1,
#          'shopping': 1,
#          'centre': 1,
#          'starting': 1,
#          'music': 3,
#          'cool': 1,
#          'collect': 1,
#          'angsty': 2,
#          'rock': 3,
#          'stage': 1,
#          'black': 2,
#          'skinny': 3,
#          'jeans': 2,
#          'phase': 1,
#          'else': 1,
#          'truly': 1,
#          'believed': 1,
#          'jeans…': 1,
#          'goodness': 1,
#          'grunge': 1,
#          'truthfully': 1,
#          'goes': 1,
#          'yours': 1,
#          'brother': 1,
#          '‘group’': 1,
#          'belong': 2,
#          'group': 1,
#          'friends': 2,
#          'pj': 1,
#          'max': 1,
#          'played': 1,
#          'sounds': 1,
#          'right…': 1,
#          'electric': 1,
#          'lesson': 1,
#          'shame': 1,
#          'cello': 1,
#          'plus': 1,
#          'forced': 1,
#          'play': 1,
#          'appreciate': 1,
#          'skateboarding': 1,
#          'talking': 1,
#          'tricks': 1,
#          'lessons': 1,
#          'hundreds': 1,
#          'ended': 1,
#          'of…': 1,
#          'computer': 3,
#          'geeky': 1,
#          'opposite': 1,
#          'proud': 2,
#          'help': 1,
#          'self': 1,
#          'generation': 1,
#          'use': 1,
#          'correctly': 1,
#          'period': 1,
#          'normally': 1,
#          'suppose': 3,
#          'experiences…': 1,
#          'spoke': 1,
#          'surprised': 1,
#          'opinion': 1,
#          'hard': 1,
#          'interesting': 1,
#          'converse': 1,
#          'degree': 1,
#          'interaction': 1,
#          'view': 1,
#          'differences': 1,
#          'men': 1,
#          'women': 1,
#          'shout': 1,
#          'choose': 2,
#          'ignore': 1,
#          'worse': 1,
#          ...})
